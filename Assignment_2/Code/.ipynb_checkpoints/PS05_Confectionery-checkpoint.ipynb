# %% [markdown]
# <h1>Assignment 2 - PS05 - [Confectionery]</h1>

# %%
class Confectionery:
    
    # # # # # # # Function 1 # # # # # # # 
    # Reads the '/' separated list from the input file,
    # converts it into a graph 
    # and prepares the adjacency list
    def readApplications(self, inputfile):
        try:
            with open(inputfile) as file:
                for line in file:
                    l = line.split('/')
                    i = 0
                    for ln in l:
                        l[i] = ln.strip()
                        i += 1
                    self.adj_list[l[0]] = l[1:]
        except IOError:
            print("Could not read file:", inputfile)

# %%
def readConfectioneries(inputfile):
    chocolate = []
    number = []
    order = 0 # 0 implies ascending and 1 implies descending order
    try:
        with open(inputfile) as file:
            for line in file:
                if line.lower().startswith('chocolate:'):
                        #print(line)
                        l = line.split(':')
                        #print(l)
                        chocolate = l[1].split('/')
                        #print(chocolate)
                        i = 0
                        for ln in chocolate:
                            chocolate[i] = ln.strip()
                            i += 1
                        print(chocolate)
                        
                elif line.lower().startswith('number:'):
                        #print(line)
                        l = line.split(':')
                        #print(l)
                        number = l[1].split('/')
                        #print(number)
                        i = 0
                        for ln in number:
                            number[i] = int(ln.strip())
                            i += 1
                        print(number)
                        
                elif line.lower().startswith('order chocolate by number:'):
                        #print(line)
                        l = line.split(':')
                        #print(l)
                        l[1] = l[1].strip()
                        #print(l)
                        if l[1].lower() == "low to high":
                            order = 1
                        print(order)
            
    except IOError:
        print("Could not read file:", inputfile)
            
input_file = 'inputPS05.txt'
readConfectionaries(input_file)
# Out:
# ['Nestle', 'Amul', 'Parle', 'M&M', 'Mars', 'Campco']
# [123, 231, 89, 156, 99, 278]
# 0

# %%
class Graph:
    
    # Class constructor
    def __init__(self):
        # Declaring adjacency list
        self.adj_list = {}        
        # Declaring files related to the program
        self.input_file = ''
        self.output_file = ''
        self.prompts_file = ''
        
        
    # # # # Internal function # # # # 
    # Traverses vertically through the adjacency list and 
    # returns Instructors name as a list
    def getCandidatesList(self, ad_list):
        return ad_list.keys()
    
    
    # # # # Internal function # # # # 
    # Traverses Horizontally through the adjacency list in a BFS fashion and 
    # returns unique courses as a list
    def getCoursesList(self, ad_list):
        sub_list = {''}
        for val in ad_list.values():
            sub_list = sub_list.union(set(val))
        return [*sub_list][1:]

    
    # Internal function: reads the promptsPS7.txt file and 
    # calls the corresponding functions
    def handlePrompts(self, promptsFile):   
        try: 
            with open(promptsFile) as f:
                for line in f:
                    line = line.rstrip('\n')

                    if line.startswith('showMinList'):
                        self.displayHireList()

                    elif line.startswith('searchCourse:'):
                        l = line.split(': ')[1]
                        self.displayCandidates(l)
                    
                    # If Part A prompt present,
                    # Check the next prompt has PartB
                    elif line.startswith('Part A:'):
                        l1 = line.split(': ')[1]
                        try:
                            line2 = next(f)
                            line2 = line2.rstrip('\n')
                        except:
                            print('Part B not specified')
                            break
                        if line2.startswith('Part B:'):
                            l2 = line2.split(': ')[1]
                            self.findCourseInstructors(l1, l2)
                        else:
                            print('Part B not specified')
                            
                    # If "Part B" prompt present,
                    # Check the next prompt has "Part A"
                    elif line.startswith('Part B:'):
                        l1 = line.split(': ')[1]
                        try:
                            line2 = next(f)
                            line2 = line2.rstrip('\n')
                        except:
                            print('Part A not specified')
                            break
                        if line2.startswith('Part A:'):
                            l2 = line2.split(': ')[1]
                            self.findCourseInstructors(l2, l1)
                        else:
                            print('Part A not specified')
                    else:
                        print("Undefined prompt")
                        
        except OSError:
            print("Failed opening the file")

    
    # # # # # # # Function 1 # # # # # # # 
    # Reads the '/' separated list from the input file,
    # converts it into a graph 
    # and prepares the adjacency list
    def readApplications(self, inputfile):
        try:
            with open(inputfile) as file:
                for line in file:
                    l = line.split('/')
                    i = 0
                    for ln in l:
                        l[i] = ln.strip()
                        i += 1
                    self.adj_list[l[0]] = l[1:]
        except IOError:
            print("Could not read file:", inputfile)
            
    
    # # # # # # # Function 2 # # # # # # # 
    # Gets the list of all instructors and their courses
    # and writes the info into the output file
    def showAll(self):
        try:
            with open(self.output_file, mode = 'w') as f:
                f.write('--------Function showAll--------\n')
                names_list = self.getCandidatesList(self.adj_list)
                courses_list = self.getCoursesList(self.adj_list)
                f.write("\nTotal no. of candidates: ")
                f.write(str(len( names_list )))
                f.write("\nTotal no. of courses: ")
                f.write(str(len( courses_list )))
                f.write("\n\nList of candidates:\n\n")
                f.writelines(["%s\n" %item for item in names_list])
                f.write("\nList of courses:\n\n")
                f.writelines(["%s\n" %item for item in courses_list])
                f.write("-"*65 + '\n')
                
        except OSError:
            print("Failed creating the file")
            
            
    # # # # # # # Function 3 # # # # # # # 
    # Traverses through the adjacency list and Shows the 
    # minimum list of candidates for the given course
    def displayHireList(self):
        
        # To prepare the weighted list of instructors
        # Weight - no. of subjects taught by the instructor
        instr_list = {}
        for k,v in self.adj_list.items():
            instr_list[k] = len(v)
            
        # Sorting the weighted list in descending order of weights
        weighted_names = dict(sorted(instr_list.items(), key=lambda item: item[1], reverse=True))
        
        # Get the unique course list
        course_list = self.getCoursesList(self.adj_list)
        min_list = {''}     
        
        # Iterate over the course list and prepare the minimum list
        for key in weighted_names.keys():
            if key in self.adj_list.keys():
                value = self.adj_list[key]
                for course in value:
                    try:
                        # Removing the matching subjects from course list
                        course_list.remove(course)
                        min_list.add(key)
                    except:
                        pass
                    
        # Removing the initial '' item from list
        min_list = [*min_list][1:]
        
        # Get the subject corresponding to the candidates in minlist
        # and write it to putput file
        inpf = open(self.input_file)
        try:
            with open(self.output_file, mode = 'a') as opf:
                opf.write('\n--------Function displayHireList--------\n')
                opf.write('\nNo. of candidates required to cover most of the courses: %d\n\n' %len(min_list))
                for line in inpf:
                    for instr in min_list:
                        if line.startswith(instr):
                            opf.write(line)
                opf.write("-"*65)
                
        except OSError:
            print("Failed opening the file")
        inpf.close()

                        
    # # # # # # # Function 4 # # # # # # # 
    # Traverses the adjacency list and 
    # Shows the list of candidates for the given course
    def displayCandidates(self, course):
        found = 0
        k = []
        
        try:
            with open(self.output_file, mode = 'a') as f:
                for key, val in self.adj_list.items():
                    if course in val:
                        k.append(key)
                        found = 1
                if found == 1:
                    f.write('\n\n--------Function displayCandidates--------\n')
                    f.write('\nList of Candidates who can handle ' + course +':\n')
                    for key in k:
                        f.write('\n'+ key)
                    f.write('\n' + "-"*65)
                else:
                    f.write('\n\n--------Function displayCandidates--------\n')
                    f.write("\nNo candidate can handle " + course +'\n')
                    f.write('\n' + "-"*65)
        except OSError:
            print("Failed opening the file")
            
    
    # # # # # # # Function 5 # # # # # # # 
    # Writes the list of course instructors for Part A, Part B to the output file
    def findCourseInstructors(self, PartA, PartB):
        partA_instr = []
        partB_instr = []
        
        for key, val in self.adj_list.items():
            if PartA in val:
                partA_instr.append(key)

            if PartB in val:
                partB_instr.append(key)

        try:
            with open(self.output_file, mode = 'a') as f:
                f.write('\n\n--------Function findCourseInstructors--------\n\n')
                print('Part A:', PartA, file = f)
                print('Part B:', PartB, file = f)
                print('\nCourse Instructors:\n', file = f)
                f.write('Part A: ')
                print(*partA_instr, sep = ',', file = f)
                f.write('Part B: ')
                print(*partB_instr, sep = ',', file = f)
                f.write("-"*65)
                
        except OSError:
            print("Failed opening the file")

            
# Driver code
if __name__ == "__main__":
    # Create a graph from contents in 'inputPS7.txt'
    g = Graph()
    g.input_file = 'inputPS7.txt'
    g.output_file = 'outputPS7.txt'
    g.prompts_file = 'promptsPS7.txt'
    g.readApplications(g.input_file)
    g.showAll()
    g.handlePrompts(g.prompts_file)
